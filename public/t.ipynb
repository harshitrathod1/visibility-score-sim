# %%
import pandas as pd

# %%
df = pd.read_csv("./company_impressions_data_v2.csv")

# %%
df
# Out:
#        pi              piName  iec_range      cohort_id  companyId  \
# 0      21  Financial Services  1001-5000   1001-5000_21         83
# 1      21  Financial Services  1001-5000   1001-5000_21      12312
# 2      21  Financial Services  1001-5000   1001-5000_21     932545
# 3      21  Financial Services  1001-5000   1001-5000_21      12252
# 4      21  Financial Services  1001-5000   1001-5000_21     810893
# ...   ...                 ...        ...            ...        ...
# 6044  159     Auto Components  1001-5000  1001-5000_159     286419
# 6045  159     Auto Components  1001-5000  1001-5000_159      18934
# 6046  159     Auto Components  1001-5000  1001-5000_159     241606
# 6047  159     Auto Components  1001-5000  1001-5000_159     172548
# 6048  159     Auto Components  1001-5000  1001-5000_159     590136
#
#       avg_monthly_impressions      p99     p100  total_companies_in_cohort  \
# 0                     50693.0  35134.5  50693.0                        150
# ...
